# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,10,1000)

y1 = ((x + 1)/(x - 1))
y2 = x + 2*np.log(np.abs(x-1))

plt.xlim(0,5)
plt.ylim(-5,50)

plt.vlines(0, -100, 100)
plt.hlines(0, -100, 100)

plt.plot(x,y1)
plt.plot(x,y2)

plt.show()
